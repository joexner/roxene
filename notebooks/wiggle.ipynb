# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import sys
 
sys.path.append('..')

# %%
from roxene.mutagens import wiggle

rng = np.random.default_rng(1235)
x = rng.uniform(-1, 1, (10000))
y = wiggle(x, rng, 0.03, 0.001)
plt.scatter(x, y, s=1)
plt.scatter(x, y-x, s=1)
plt.grid(True)
plt.show()
